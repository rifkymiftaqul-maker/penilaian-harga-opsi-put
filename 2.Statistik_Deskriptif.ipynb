# %%
#IMPORT LIBRARY
import pandas as pd
import numpy as np

# %%
# STATISTIK DESKRIPTIF UNTUK DATA HARGA PENUTUPAN HARIAN SAHAM
df = pd.read_excel("Data_Harga_Penutupan_Harian_Saham.xlsx")
df["UNDERLYING_LAST"].describe()
# Out:
# count    532.000000
# mean     276.498477
# std      119.111507
# min      112.320000
# 25%      171.645000
# 50%      243.890000
# 75%      409.070000
# max      504.090000
# Name: UNDERLYING_LAST, dtype: float64

# %%
# STATISTIK DESKRIPTIF UNTUK DATA HARGA BID DAN ASK
df = pd.read_csv("Data_Kuotasi_Opsi_Put_NVDA_Cleaning.csv")
df[["P_BID", "P_ASK"]].describe()
# Out:
#                P_BID          P_ASK
# count  697267.000000  697267.000000
# mean       85.905223      87.734759
# std       114.231194     115.910074
# min         0.000000       0.010000
# 25%         1.560000       1.770000
# 50%        31.600000      32.800000
# 75%       135.450000     138.650000
# max       594.550000     601.400000

# %%
# STATISTIK DESKRIPTIF UNTUK DATA HARGA PELAKSANAAN
df["STRIKE"].describe()
# Out:
# count    697267.000000
# mean        333.699226
# std         210.594834
# min           5.000000
# 25%         165.000000
# 50%         290.000000
# 75%         460.000000
# max        1000.000000
# Name: STRIKE, dtype: float64
